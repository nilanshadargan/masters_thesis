# %% [markdown]
# ### Imports

# %%
import pandas as pd
import os
import numpy as np
from collections import Counter
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import ast
from nltk.tokenize import word_tokenize
nltk.download('punkt')
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from tqdm import tqdm
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/nilanshadargan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/nilanshadargan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### Data Loading

# %%
ycd_data = 'Data/2023-07-13-yc-companies.csv'

# %%
ycd = pd.read_csv(ycd_data)

# %%
#Change column from string to list of strings
ycd['tags'] = ycd['tags'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) and x.startswith('[') else x)

# %%
#Collecting AI companies
ai_companies = ycd[ycd['tags'].apply(lambda tags: 'Artificial Intelligence' in tags if isinstance(tags, list) else False)]
ai_companies = ai_companies.drop_duplicates(subset=['company_name'])
print(ai_companies)
# Out:
#       company_id company_name  \
# 2          28409      BerriAI
# 9          28367    Atri Labs
# 22         28183        Metal
# 44         28114    BabylonAI
# 49         28089       Thread
# ...          ...          ...
# 4386       27871       Extend
# 4390       27860      Dream3D
# 4414       27822     Zenfetch
# 4432       27763       Double
# 4617       26825   Flair Labs
#
#                                       short_description  \
# 2                Stop OpenAI Errors w/ 1 line of code 👈
# 9       Open-source web framework for Python developers
# 22             Machine learning embeddings as a service
# 44         Datadog for machine learning on edge devices
# 49     Incident Management platform for large enterp...
# ...                                                 ...
# 4386         AI-Powered Workflows for Unstructured Data
# 4390                               AI-powered 3D Design
# 4414  Real time call intelligence for technical sale...
# 4432       The IDE for prompt based no-code automations
# 4617   Unlock insights from conversation data with LLMs
#
#                                        long_description batch  status  \
# 2     Stop OpenAI Errors in 1 line of code\r\n\r\n``...   W23  Active
# 9     Atri Labs is Vercel for Python developers. \r\...   W23  Active
# 22    Metal does machine learning embeddings as a se...   W23  Active
# 44    BabylonAI (YC W23) is a smart logging SDK for ...   W23  Active
# 49    Thread is an incident management tool for larg...   W23  Active
# ...                                                 ...   ...     ...
# 4386  Intelligent data extraction and automation too...   W23  Active
# 4390  Dream3D is an AI-powered 3D design tool that m...   W23  Active
# 4414  Zenfetch is a real-time call assistant for tec...   W23  Active
# 4432  Double is an IDE for prompt based no-code auto...   W23  Active
# 4617  Flair ingests unstructured voice data with LLM...   S22  Active
#
#                                                    tags          location  \
# 2     [Artificial Intelligence, Developer Tools, Gen...     San Francisco
# 9     [Artificial Intelligence, Developer Tools, Ope...     San Francisco
# 22    [Artificial Intelligence, Machine Learning, B2...          New York
# 44    [Artificial Intelligence, Developer Tools, Mac...     San Francisco
# 49    [Artificial Intelligence, Developer Tools, B2B...     San Francisco
# ...                                                 ...               ...
# 4386  [Artificial Intelligence, SaaS, B2B, Enterpris...     San Francisco
# 4390  [Artificial Intelligence, Generative AI, Compu...          New York
# 4414  [Artificial Intelligence, Generative AI, SaaS,...     San Francisco
# 4432  [Artificial Intelligence, Robotic Process Auto...  Redwood City, CA
# 4617  [Artificial Intelligence, Generative AI, NLP, ...       Seattle, WA
#
#      country  year_founded  num_founders  \
# 2         US        2023.0             2
# 9         US        2022.0             2
# 22        US        2023.0             3
# 44        US        2023.0             2
# 49        US        2023.0             3
# ...      ...           ...           ...
# 4386      US        2023.0             1
# 4390      US        2022.0             2
# 4414      US        2022.0             2
# 4432      US        2022.0             2
# 4617      US        2022.0             2
#
#                                          founders_names  team_size  \
# 2                  ['Krrish Dholakia', 'Ishaan Jaffer']        2.0
# 9              ['Darshita Chaturvedi', 'Shyam Swaroop']        2.0
# 22     ['Taylor Lowe', "James O'Dwyer", 'Sergio Prada']        3.0
# 44                  ['Rangel Milushev', 'Ahmad Roumie']        2.0
# 49    ['Yuheng Wang', 'Harsha Vankayalapati', 'Akeem...        3.0
# ...                                                 ...        ...
# 4386                                 ['Kushal Byatnal']        3.0
# 4390              ['Tony Francis', 'Justin Woodbridge']        2.0
# 4414             ['Akash Mandavilli', 'Gabe Villasana']        2.0
# 4432          ['Wesley Yue', 'Gonzalo Espinoza Graham']        2.0
# 4617                       ['Samir Sen', 'Trevor Tsue']        2.0
#
#                         website  \
# 2             https://berri.ai/
# 9          https://atrilabs.com
# 22         https://getmetal.io/
# 44        https://babylonai.dev
# 49      http://www.usethread.io
# ...                         ...
# 4386    https://www.extend.app/
# 4390        https://dream3d.com
# 4414  https://www.zenfetch.com/
# 4432      https://usedouble.com
# 4617  https://www.flairlabs.ai/
#
#                                                  cb_url  \
# 2                                                   NaN
# 9                                                   NaN
# 22                                                  NaN
# 44                                                  NaN
# 49    https://www.crunchbase.com/organization/thread...
# ...                                                 ...
# 4386                                                NaN
# 4390                                                NaN
# 4414                                                NaN
# 4432                                                NaN
# 4617                                                NaN
#
#                                            linkedin_url
# 2            https://www.linkedin.com/company/berri-ai/
# 9           https://www.linkedin.com/company/atri-labs/
# 22     https://www.linkedin.com/company/getmetal/about/
# 44          https://www.linkedin.com/company/babylonai/
# 49    https://www.linkedin.com/company/thread-incorp...
# ...                                                 ...
# 4386        https://www.linkedin.com/company/extend-app
# 4390                                                NaN
# 4414         https://www.linkedin.com/company/zenfetch/
# 4432         https://www.linkedin.com/company/double-ai
# 4617     https://www.linkedin.com/company/flair-labs-1/
#
# [319 rows x 16 columns]

# %%
def scrape_website(url, company_name):
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        texts = soup.stripped_strings
        # Print the company name
        print(f"Scraping website for {company_name}")
        return ' '.join(texts)
    except requests.RequestException:
        return 'Failed to retrieve'




ai_companies['Scraped_Info'] = ai_companies.apply(lambda x: scrape_website(x['website'], x['company_name']), axis=1)

# # Create a new column for the scraped information
# ai_companies['Scraped_Info'] = ai_companies['website'].progress_apply(scrape_website)
# Out:
# Scraping website for Atri Labs
# Scraping website for Metal
# Scraping website for BabylonAI
# Scraping website for Thread
# Scraping website for MagnaPlay
# Scraping website for Waveline
# Scraping website for UpTrain AI
# Scraping website for Defog.ai
# Scraping website for 222
# Scraping website for Hadrius
# Scraping website for Fintool
# Scraping website for Orchid
# Scraping website for Booth AI
# Scraping website for Wild Moose
# Scraping website for EzDubs
# Scraping website for Magicflow 𐂂
# Scraping website for Qventus
# Scraping website for Dabble
# Scraping website for Paperspace
# Scraping website for SigOpt
# Scraping website for Smarking
# Scraping website for 20n
# Scraping website for Checkr
# Scraping website for Weave
# Scraping website for SalesSift
# Scraping website for OpenCurriculum
# Scraping website for MixerBox
# Scraping website for Casetext
# Scraping website for RADAR
# Scraping website for Canopy Labs
# Scraping website for LeadGenius
# Scraping website for Directed Edge
# Scraping website for Taylor AI
# Scraping website for Martin
# Scraping website for Orbio Earth
# Scraping website for Simbie Health
# Scraping website for FlowiseAI
# Scraping website for Nowadays
# Scraping website for AiSDR
# Scraping website for dili
# Scraping website for Quill AI
# Scraping website for Cyclone
# Scraping website for sudocode
# Scraping website for Andromeda Surgical
# Scraping website for Roundtable
# Scraping website for Inlet
# Scraping website for SafetyKit
# Scraping website for Osium AI
# Scraping website for Pincites
# Scraping website for Haven
# Scraping website for Unhaze
# Scraping website for Epsilla
# Scraping website for Arcimus
# Scraping website for Docsum
# Scraping website for Agentive
# Scraping website for Cerelyze
# Scraping website for SID
# Scraping website for Every, Inc.
# Scraping website for Solve Intelligence
# Scraping website for Cedana
# Scraping website for Pointhound
# Scraping website for kapa.ai
# Scraping website for Leafpress
# Scraping website for Persana AI
# Scraping website for Gloo
# Scraping website for Squack
# Scraping website for Extend
# Scraping website for Zenfetch
# Scraping website for Double
# Scraping website for Flair Labs

# %%
scraped_ai  = ai_companies

# Filter out rows where 'Scraped_Info' column contains 'Failed to retrieve'
scraped_ai = scraped_ai[(scraped_ai['Scraped_Info'] != 'Failed to retrieve') & (scraped_ai['Scraped_Info'].notna())]

# %%
scraped_ai = scraped_ai.drop_duplicates(subset=['company_name'])
print(scraped_ai)

# Save the updated dataset
scraped_ai.to_csv('scraped_ai.csv', index=False)
# Out:
#       company_id company_name  \
# 9          28367    Atri Labs
# 22         28183        Metal
# 44         28114    BabylonAI
# 49         28089       Thread
# 72         27989    MagnaPlay
# ...          ...          ...
# 4382       27874       Squack
# 4386       27871       Extend
# 4414       27822     Zenfetch
# 4432       27763       Double
# 4617       26825   Flair Labs
#
#                                       short_description  \
# 9       Open-source web framework for Python developers
# 22             Machine learning embeddings as a service
# 44         Datadog for machine learning on edge devices
# 49     Incident Management platform for large enterp...
# 72                         AI-powered game translation.
# ...                                                 ...
# 4382         Natural language RPA tools for accountants
# 4386         AI-Powered Workflows for Unstructured Data
# 4414  Real time call intelligence for technical sale...
# 4432       The IDE for prompt based no-code automations
# 4617   Unlock insights from conversation data with LLMs
#
#                                        long_description batch  status  \
# 9     Atri Labs is Vercel for Python developers. \r\...   W23  Active
# 22    Metal does machine learning embeddings as a se...   W23  Active
# 44    BabylonAI (YC W23) is a smart logging SDK for ...   W23  Active
# 49    Thread is an incident management tool for larg...   W23  Active
# 72    MagnaPlay is game translation simplified into ...   W23  Active
# ...                                                 ...   ...     ...
# 4382  Squack gives accounting firms a RPA tool that ...   W23  Active
# 4386  Intelligent data extraction and automation too...   W23  Active
# 4414  Zenfetch is a real-time call assistant for tec...   W23  Active
# 4432  Double is an IDE for prompt based no-code auto...   W23  Active
# 4617  Flair ingests unstructured voice data with LLM...   S22  Active
#
#                                                    tags          location  \
# 9     [Artificial Intelligence, Developer Tools, Ope...     San Francisco
# 22    [Artificial Intelligence, Machine Learning, B2...          New York
# 44    [Artificial Intelligence, Developer Tools, Mac...     San Francisco
# 49    [Artificial Intelligence, Developer Tools, B2B...     San Francisco
# 72              [Artificial Intelligence, SaaS, Gaming]     San Francisco
# ...                                                 ...               ...
# 4382  [Artificial Intelligence, Developer Tools, Saa...     San Francisco
# 4386  [Artificial Intelligence, SaaS, B2B, Enterpris...     San Francisco
# 4414  [Artificial Intelligence, Generative AI, SaaS,...     San Francisco
# 4432  [Artificial Intelligence, Robotic Process Auto...  Redwood City, CA
# 4617  [Artificial Intelligence, Generative AI, NLP, ...       Seattle, WA
#
#      country  year_founded  num_founders  \
# 9         US        2022.0             2
# 22        US        2023.0             3
# 44        US        2023.0             2
# 49        US        2023.0             3
# 72        US        2023.0             2
# ...      ...           ...           ...
# 4382      US        2022.0             3
# 4386      US        2023.0             1
# 4414      US        2022.0             2
# 4432      US        2022.0             2
# 4617      US        2022.0             2
#
#                                          founders_names  team_size  \
# 9              ['Darshita Chaturvedi', 'Shyam Swaroop']        2.0
# 22     ['Taylor Lowe', "James O'Dwyer", 'Sergio Prada']        3.0
# 44                  ['Rangel Milushev', 'Ahmad Roumie']        2.0
# 49    ['Yuheng Wang', 'Harsha Vankayalapati', 'Akeem...        3.0
# 72                 ['Pedro Esteves', 'Paulo Rodrigues']        3.0
# ...                                                 ...        ...
# 4382  ['Preston Zhou', 'Elijah Sorey', 'Eitan Borgnia']        3.0
# 4386                                 ['Kushal Byatnal']        3.0
# 4414             ['Akash Mandavilli', 'Gabe Villasana']        2.0
# 4432          ['Wesley Yue', 'Gonzalo Espinoza Graham']        2.0
# 4617                       ['Samir Sen', 'Trevor Tsue']        2.0
#
#                         website  \
# 9          https://atrilabs.com
# 22         https://getmetal.io/
# 44        https://babylonai.dev
# 49      http://www.usethread.io
# 72        https://magnaplay.com
# ...                         ...
# 4382           http://squack.io
# 4386    https://www.extend.app/
# 4414  https://www.zenfetch.com/
# 4432      https://usedouble.com
# 4617  https://www.flairlabs.ai/
#
#                                                  cb_url  \
# 9                                                   NaN
# 22                                                  NaN
# 44                                                  NaN
# 49    https://www.crunchbase.com/organization/thread...
# 72                                                  NaN
# ...                                                 ...
# 4382                                                NaN
# 4386                                                NaN
# 4414                                                NaN
# 4432                                                NaN
# 4617                                                NaN
#
#                                            linkedin_url  \
# 9           https://www.linkedin.com/company/atri-labs/
# 22     https://www.linkedin.com/company/getmetal/about/
# 44          https://www.linkedin.com/company/babylonai/
# 49    https://www.linkedin.com/company/thread-incorp...
# 72          https://www.linkedin.com/company/magnaplay/
# ...                                                 ...
# 4382                                                NaN
# 4386        https://www.linkedin.com/company/extend-app
# 4414         https://www.linkedin.com/company/zenfetch/
# 4432         https://www.linkedin.com/company/double-ai
# 4617     https://www.linkedin.com/company/flair-labs-1/
#
#                                            Scraped_Info
# 9     AI Insurance by Atri Insurance Solutions Polic...
# 22    AI for Financial Analysts | Metal metal. Secur...
# 44
# 49    Customer Success Launch Home Contact The Lifel...
# 72    MagnaPlay Localizing games should be child's p...
# ...                                                 ...
# 4382  Computron by Squack Blog Build data workflows ...
# 4386                                             Extend
# 4414                               Zenfetch Personal AI
# 4432  Double | Find and convert leads with hyper-tar...
# 4617  Flairlabs.ai - Voice AI & copilot for call cen...
#
# [292 rows x 17 columns]

# %% [markdown]
# ## Modifications and data cleaning

# %%
filtered_data = scraped_ai[scraped_ai['Scraped_Info'].str.len() >= 100]

# %%
filtered_data
# Out:
#       company_id company_name  \
# 9          28367    Atri Labs
# 22         28183        Metal
# 49         28089       Thread
# 72         27989    MagnaPlay
# 92         27966   UpTrain AI
# ...          ...          ...
# 4218       28743    Leafpress
# 4243       28301   Persana AI
# 4382       27874       Squack
# 4432       27763       Double
# 4617       26825   Flair Labs
#
#                                       short_description  \
# 9       Open-source web framework for Python developers
# 22             Machine learning embeddings as a service
# 49     Incident Management platform for large enterp...
# 72                         AI-powered game translation.
# 92             Open source Datadog for Machine Learning
# ...                                                 ...
# 4218                       ESG Software for Real Estate
# 4243  Intelligent sales copilot powered by fine tune...
# 4382         Natural language RPA tools for accountants
# 4432       The IDE for prompt based no-code automations
# 4617   Unlock insights from conversation data with LLMs
#
#                                        long_description batch  status  \
# 9     Atri Labs is Vercel for Python developers. \r\...   W23  Active
# 22    Metal does machine learning embeddings as a se...   W23  Active
# 49    Thread is an incident management tool for larg...   W23  Active
# 72    MagnaPlay is game translation simplified into ...   W23  Active
# 92    UpTrain is an open-source tool to improve AI m...   W23  Active
# ...                                                 ...   ...     ...
# 4218  Leafpress simplifies ESG for real estate portf...   S23  Active
# 4243  Persana AI is an intelligent sales copilot pow...   W23  Active
# 4382  Squack gives accounting firms a RPA tool that ...   W23  Active
# 4432  Double is an IDE for prompt based no-code auto...   W23  Active
# 4617  Flair ingests unstructured voice data with LLM...   S22  Active
#
#                                                    tags          location  \
# 9     [Artificial Intelligence, Developer Tools, Ope...     San Francisco
# 22    [Artificial Intelligence, Machine Learning, B2...          New York
# 49    [Artificial Intelligence, Developer Tools, B2B...     San Francisco
# 72              [Artificial Intelligence, SaaS, Gaming]     San Francisco
# 92    [Artificial Intelligence, Developer Tools, Gen...     San Francisco
# ...                                                 ...               ...
# 4218  [Artificial Intelligence, Real Estate, B2B, Pr...     San Francisco
# 4243    [Artificial Intelligence, Generative AI, Sales]     San Francisco
# 4382  [Artificial Intelligence, Developer Tools, Saa...     San Francisco
# 4432  [Artificial Intelligence, Robotic Process Auto...  Redwood City, CA
# 4617  [Artificial Intelligence, Generative AI, NLP, ...       Seattle, WA
#
#      country  year_founded  num_founders  \
# 9         US        2022.0             2
# 22        US        2023.0             3
# 49        US        2023.0             3
# 72        US        2023.0             2
# 92        US        2022.0             2
# ...      ...           ...           ...
# 4218      US        2023.0             2
# 4243      US        2023.0             2
# 4382      US        2022.0             3
# 4432      US        2022.0             2
# 4617      US        2022.0             2
#
#                                          founders_names  team_size  \
# 9              ['Darshita Chaturvedi', 'Shyam Swaroop']        2.0
# 22     ['Taylor Lowe', "James O'Dwyer", 'Sergio Prada']        3.0
# 49    ['Yuheng Wang', 'Harsha Vankayalapati', 'Akeem...        3.0
# 72                 ['Pedro Esteves', 'Paulo Rodrigues']        3.0
# 92                ['Sourabh Agrawal', 'Shikha Mohanty']        4.0
# ...                                                 ...        ...
# 4218                      ['Devishi Jha', 'Jianna Liu']        2.0
# 4243                    ['Sriya Maram', 'Rush Shahani']        2.0
# 4382  ['Preston Zhou', 'Elijah Sorey', 'Eitan Borgnia']        3.0
# 4432          ['Wesley Yue', 'Gonzalo Espinoza Graham']        2.0
# 4617                       ['Samir Sen', 'Trevor Tsue']        2.0
#
#                         website  \
# 9          https://atrilabs.com
# 22         https://getmetal.io/
# 49      http://www.usethread.io
# 72        https://magnaplay.com
# 92          https://uptrain.ai/
# ...                         ...
# 4218   https://www.leafpress.io
# 4243    https://www.persana.ai/
# 4382           http://squack.io
# 4432      https://usedouble.com
# 4617  https://www.flairlabs.ai/
#
#                                                  cb_url  \
# 9                                                   NaN
# 22                                                  NaN
# 49    https://www.crunchbase.com/organization/thread...
# 72                                                  NaN
# 92                                                  NaN
# ...                                                 ...
# 4218                                                NaN
# 4243                                                NaN
# 4382                                                NaN
# 4432                                                NaN
# 4617                                                NaN
#
#                                            linkedin_url  \
# 9           https://www.linkedin.com/company/atri-labs/
# 22     https://www.linkedin.com/company/getmetal/about/
# 49    https://www.linkedin.com/company/thread-incorp...
# 72          https://www.linkedin.com/company/magnaplay/
# 92          https://www.linkedin.com/company/uptrain-ai
# ...                                                 ...
# 4218                                                NaN
# 4243  https://www.linkedin.com/company/persana-ai/?v...
# 4382                                                NaN
# 4432         https://www.linkedin.com/company/double-ai
# 4617     https://www.linkedin.com/company/flair-labs-1/
#
#                                            Scraped_Info
# 9     AI Insurance by Atri Insurance Solutions Polic...
# 22    AI for Financial Analysts | Metal metal. Secur...
# 49    Customer Success Launch Home Contact The Lifel...
# 72    MagnaPlay Localizing games should be child's p...
# 92    UpTrain | Full-Stack LLMOps Platform 📝 Read ou...
# ...                                                 ...
# 4218  Leafpress Enterprise solution Team Why us FAQ ...
# 4243  Persana AI | Supercharge your Prospecting with...
# 4382  Computron by Squack Blog Build data workflows ...
# 4432  Double | Find and convert leads with hyper-tar...
# 4617  Flairlabs.ai - Voice AI & copilot for call cen...
#
# [244 rows x 17 columns]

# %%
filtered_data.to_csv('filtered_data.csv', index=False)
